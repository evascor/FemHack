# %%
import pandas as pd

# %%
df = pd.read_csv('test.csv')

# %%
df.head()
# Out:
#    test_idx                                              title  \
# 0         0                      Get my case heard for neglect
# 1         1  JUSTICE POUR JOE ET DAX: pour une peine exempl...
# 2         2   Mandatory Course in Mental Health for Highschool
# 3         3  Stop coronavirus - call for permanent ban on c...
# 4         4  Chiedere alle Nazioni Unite che il 2018 sia l'...
#
#                                          description  \
# 0  son in another empty labor and delivery room l...
# 1  Le 13 Février 2018, 3 chiens étaient déposés c...
# 2  In any given year, 1 in 5 people in Canada wil...
# 3  Français\nрусский \nPlease take action to supp...
# 4  population?- induced as they are by violence, ...
#
#                                               target        creator_name  \
# 0  ['Virginia Governor', 'St francis hospital', '...          tyra reyes
# 1  ['Pétition adressée à Nicole Belloubet', 'Cyri...      Daniel MADEIRA
# 2  ['The Minister Of Education', 'Halton Catholic...      Jayme Robinson
# 3  ["National People's Congress (NPC)", 'WHO', 'O...   ACTAsia Education
# 4  ['Petizione diretta a Assemblea Generale Nazio...  Cristiana Fiamingo
#
#                            creator_location  supporters  \
# 0               Richmond, VA, United States      149447
# 1                                    France       53919
# 2                          Oakville, Canada       30635
# 3                            United Kingdom       48004
# 4  Università degli Studi di Milano, Italia         436
#
#                    created_date  \
# 0                 Oct. 26, 2017
# 1  Date de création 10 mai 2019
# 2                  Jun 11, 2018
# 3                   20 Feb 2020
# 4    Data di lancio 27 lug 2017
#
#                                         banner_image  \
# 0  https://assets.change.org/photos/3/sq/fl/Klsqf...
# 1  https://assets.change.org/photos/7/xj/js/ONxJJ...
# 2  https://assets.change.org/photos/8/px/bz/oupXB...
# 3  https://assets.change.org/photos/9/fc/zm/cZFCZ...
# 4  https://assets.change.org/photos/3/fd/wb/Cjfdw...
#
#                                         full_content
# 0  On 3/12/17 I was at home talking to my sister ...
# 1  Le 13 Février 2018, 3 chiens étaient déposés c...
# 2  In any given year, 1 in 5 people in Canada wil...
# 3  Français\n\nрусский\n\nPlease take action to s...
# 4  [ITA] Se osservate la lista delle annate inter...

# %%
#Comprobación existencia valores nulos
df.isna().sum()
# Limpiar valores nulos:
df_purged=df.dropna()
df_purged.isna().sum()
# Out:
# test_idx            0
# title               0
# description         0
# target              0
# creator_name        0
# creator_location    0
# supporters          0
# created_date        0
# banner_image        0
# full_content        0
# dtype: int64

# %%
# Comprobamos si existen valores duplicados
df_purged.duplicated().sum()
# Out:
# 0

# %%
#  Crear una copia explícita del DataFrame
df_purged = df_purged.copy()

# %%
# Eliminar data no relevante 
    #  Columna con la url de los banners
df_purged.drop('banner_image', axis=1, inplace=True)
    #  Columna nombre del creador
df_purged.drop('creator_name', axis=1, inplace=True)
    #  Columna fecha de creacion
df_purged.drop('created_date', axis=1, inplace=True) 
df_purged
# Out:
#      test_idx                                              title  \
# 0           0                      Get my case heard for neglect
# 1           1  JUSTICE POUR JOE ET DAX: pour une peine exempl...
# 2           2   Mandatory Course in Mental Health for Highschool
# 3           3  Stop coronavirus - call for permanent ban on c...
# 4           4  Chiedere alle Nazioni Unite che il 2018 sia l'...
# ..        ...                                                ...
# 486       486  Call for Emergency Medical Care for Children S...
# 487       487                            Restore student privacy
# 488       488  Petition the International Maritime Organizati...
# 489       489                       Keep the Arts in Our Schools
# 490       490  Save Adelaide's arts community! Save Flinders ...
#
#                                            description  \
# 0    son in another empty labor and delivery room l...
# 1    Le 13 Février 2018, 3 chiens étaient déposés c...
# 2    In any given year, 1 in 5 people in Canada wil...
# 3    Français\nрусский \nPlease take action to supp...
# 4    population?- induced as they are by violence, ...
# ..                                                 ...
# 486  relief to places devastated by natural disaste...
# 487  . Lightspeed and GoGaurdian are gross violatio...
# 488  public support in advance of this meeting will...
# 489  Talbot County Public Schools have decided to c...
# 490  Creative Arts (Drama) aka The Drama Centre. Fo...
#
#                                                 target  \
# 0    ['Virginia Governor', 'St francis hospital', '...
# 1    ['Pétition adressée à Nicole Belloubet', 'Cyri...
# 2    ['The Minister Of Education', 'Halton Catholic...
# 3    ["National People's Congress (NPC)", 'WHO', 'O...
# 4    ['Petizione diretta a Assemblea Generale Nazio...
# ..                                                 ...
# 486  ['Secretary Alex Azar', 'Secretary Kevin McAle...
# 487                      ['Princeton administratio n']
# 488      ['International Maritime Organization (IMO)']
# 489                   ['Talbot County Public Schools']
# 490                                        ['artists']
#
#                              creator_location  supporters  \
# 0                 Richmond, VA, United States      149447
# 1                                      France       53919
# 2                            Oakville, Canada       30635
# 3                              United Kingdom       48004
# 4    Università degli Studi di Milano, Italia         436
# ..                                        ...         ...
# 486        Washington D.C., DC, United States      159178
# 487                             United States         123
# 488               London, ENG, United Kingdom       89876
# 489                 Easton, MD, United States        4565
# 490                                 Australia        8616
#
#                                           full_content
# 0    On 3/12/17 I was at home talking to my sister ...
# 1    Le 13 Février 2018, 3 chiens étaient déposés c...
# 2    In any given year, 1 in 5 people in Canada wil...
# 3    Français\n\nрусский\n\nPlease take action to s...
# 4    [ITA] Se osservate la lista delle annate inter...
# ..                                                 ...
# 486  Dear Secretary Azar, Acting Secretary McAleena...
# 487  Protecting students from self harm is incredib...
# 488  In May 2021, the MV X-Press Pearl spilt 1,680 ...
# 489  Talbot County Public Schools have decided to c...
# 490  Flinders University has made the devastating d...
#
# [461 rows x 7 columns]

# %% [markdown]
# DETECCION IDIOMAS PETICIONES

# %%
# %pip install nltk
# %pip install langdetect
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# Requirement already satisfied: nltk in c:\users\fundacion\anaconda3\lib\site-packages (3.7)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\fundacion\anaconda3\lib\site-packages (from nltk) (2022.7.9)
# Requirement already satisfied: click in c:\users\fundacion\anaconda3\lib\site-packages (from nltk) (8.0.4)
# Requirement already satisfied: tqdm in c:\users\fundacion\anaconda3\lib\site-packages (from nltk) (4.64.1)
# Requirement already satisfied: joblib in c:\users\fundacion\anaconda3\lib\site-packages (from nltk) (1.1.1)
# Requirement already satisfied: colorama in c:\users\fundacion\anaconda3\lib\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: langdetect in c:\users\fundacion\anaconda3\lib\site-packages (1.0.9)
# Requirement already satisfied: six in c:\users\fundacion\anaconda3\lib\site-packages (from langdetect) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\fundacion\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\fundacion\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\fundacion\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\fundacion\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
nltk.download('omw-1.4')
from langdetect import detect

def detect_language(text):
    # Tokenización de palabras
    tokens = word_tokenize(text.lower())

    # Lematización de palabras
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(word) for word in tokens]

    # Detección del idioma
    language = detect(' '.join(tokens))
    return language
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\fundacion\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
# Creamos una columna donde guardamos el idioma de la peticion
df_purged['language'] = df_purged['title'].apply(detect_language)
df_purged
# Out:
#      test_idx                                              title  \
# 0           0                      Get my case heard for neglect
# 1           1  JUSTICE POUR JOE ET DAX: pour une peine exempl...
# 2           2   Mandatory Course in Mental Health for Highschool
# 3           3  Stop coronavirus - call for permanent ban on c...
# 4           4  Chiedere alle Nazioni Unite che il 2018 sia l'...
# ..        ...                                                ...
# 486       486  Call for Emergency Medical Care for Children S...
# 487       487                            Restore student privacy
# 488       488  Petition the International Maritime Organizati...
# 489       489                       Keep the Arts in Our Schools
# 490       490  Save Adelaide's arts community! Save Flinders ...
#
#                                            description  \
# 0    son in another empty labor and delivery room l...
# 1    Le 13 Février 2018, 3 chiens étaient déposés c...
# 2    In any given year, 1 in 5 people in Canada wil...
# 3    Français\nрусский \nPlease take action to supp...
# 4    population?- induced as they are by violence, ...
# ..                                                 ...
# 486  relief to places devastated by natural disaste...
# 487  . Lightspeed and GoGaurdian are gross violatio...
# 488  public support in advance of this meeting will...
# 489  Talbot County Public Schools have decided to c...
# 490  Creative Arts (Drama) aka The Drama Centre. Fo...
#
#                                                 target  \
# 0    ['Virginia Governor', 'St francis hospital', '...
# 1    ['Pétition adressée à Nicole Belloubet', 'Cyri...
# 2    ['The Minister Of Education', 'Halton Catholic...
# 3    ["National People's Congress (NPC)", 'WHO', 'O...
# 4    ['Petizione diretta a Assemblea Generale Nazio...
# ..                                                 ...
# 486  ['Secretary Alex Azar', 'Secretary Kevin McAle...
# 487                      ['Princeton administratio n']
# 488      ['International Maritime Organization (IMO)']
# 489                   ['Talbot County Public Schools']
# 490                                        ['artists']
#
#                              creator_location  supporters  \
# 0                 Richmond, VA, United States      149447
# 1                                      France       53919
# 2                            Oakville, Canada       30635
# 3                              United Kingdom       48004
# 4    Università degli Studi di Milano, Italia         436
# ..                                        ...         ...
# 486        Washington D.C., DC, United States      159178
# 487                             United States         123
# 488               London, ENG, United Kingdom       89876
# 489                 Easton, MD, United States        4565
# 490                                 Australia        8616
#
#                                           full_content language
# 0    On 3/12/17 I was at home talking to my sister ...       en
# 1    Le 13 Février 2018, 3 chiens étaient déposés c...       fr
# 2    In any given year, 1 in 5 people in Canada wil...       en
# 3    Français\n\nрусский\n\nPlease take action to s...       en
# 4    [ITA] Se osservate la lista delle annate inter...       it
# ..                                                 ...      ...
# 486  Dear Secretary Azar, Acting Secretary McAleena...       en
# 487  Protecting students from self harm is incredib...       ro
# 488  In May 2021, the MV X-Press Pearl spilt 1,680 ...       en
# 489  Talbot County Public Schools have decided to c...       en
# 490  Flinders University has made the devastating d...       fr
#
# [461 rows x 8 columns]

# %%
# Lista de idiomas de las peticiones
df_purged['language'].unique()
# Out:
# array(['en', 'fr', 'it', 'pt', 'tr', 'th', 'af', 'ru', 'ro', 'tl', 'ca',
#        'da', 'sk', 'de', 'nl', 'no', 'hr', 'es', 'et', 'bg', 'sv'],
#       dtype=object)

# %%
# Lista de idiomas específicos
target_languages = ['en', 'es', 'it', 'fr', 'ru']

# Filtrar el DataFrame para incluir solo las peticiones en los idiomas específicos
df_filtered = df_purged[df_purged['language'].isin(target_languages)]

# Imprimir el DataFrame filtrado
df_filtered
# Out:
#      test_idx                                              title  \
# 0           0                      Get my case heard for neglect
# 1           1  JUSTICE POUR JOE ET DAX: pour une peine exempl...
# 2           2   Mandatory Course in Mental Health for Highschool
# 3           3  Stop coronavirus - call for permanent ban on c...
# 4           4  Chiedere alle Nazioni Unite che il 2018 sia l'...
# ..        ...                                                ...
# 484       484  Support the Northwest's Clean & Equitable Ener...
# 486       486  Call for Emergency Medical Care for Children S...
# 488       488  Petition the International Maritime Organizati...
# 489       489                       Keep the Arts in Our Schools
# 490       490  Save Adelaide's arts community! Save Flinders ...
#
#                                            description  \
# 0    son in another empty labor and delivery room l...
# 1    Le 13 Février 2018, 3 chiens étaient déposés c...
# 2    In any given year, 1 in 5 people in Canada wil...
# 3    Français\nрусский \nPlease take action to supp...
# 4    population?- induced as they are by violence, ...
# ..                                                 ...
# 484  heal our oceans.\nIf we genuinely want our cle...
# 486  relief to places devastated by natural disaste...
# 488  public support in advance of this meeting will...
# 489  Talbot County Public Schools have decided to c...
# 490  Creative Arts (Drama) aka The Drama Centre. Fo...
#
#                                                 target  \
# 0    ['Virginia Governor', 'St francis hospital', '...
# 1    ['Pétition adressée à Nicole Belloubet', 'Cyri...
# 2    ['The Minister Of Education', 'Halton Catholic...
# 3    ["National People's Congress (NPC)", 'WHO', 'O...
# 4    ['Petizione diretta a Assemblea Generale Nazio...
# ..                                                 ...
# 484  ['Senator Maria Cantwell', 'Senator Patty Murr...
# 486  ['Secretary Alex Azar', 'Secretary Kevin McAle...
# 488      ['International Maritime Organization (IMO)']
# 489                   ['Talbot County Public Schools']
# 490                                        ['artists']
#
#                              creator_location  supporters  \
# 0                 Richmond, VA, United States      149447
# 1                                      France       53919
# 2                            Oakville, Canada       30635
# 3                              United Kingdom       48004
# 4    Università degli Studi di Milano, Italia         436
# ..                                        ...         ...
# 484              Vancouver, WA, United States        3233
# 486        Washington D.C., DC, United States      159178
# 488               London, ENG, United Kingdom       89876
# 489                 Easton, MD, United States        4565
# 490                                 Australia        8616
#
#                                           full_content language
# 0    On 3/12/17 I was at home talking to my sister ...       en
# 1    Le 13 Février 2018, 3 chiens étaient déposés c...       fr
# 2    In any given year, 1 in 5 people in Canada wil...       en
# 3    Français\n\nрусский\n\nPlease take action to s...       en
# 4    [ITA] Se osservate la lista delle annate inter...       it
# ..                                                 ...      ...
# 484  PLEASE SHARE WITH YOUR FRIENDS!\n\nIf we truly...       en
# 486  Dear Secretary Azar, Acting Secretary McAleena...       en
# 488  In May 2021, the MV X-Press Pearl spilt 1,680 ...       en
# 489  Talbot County Public Schools have decided to c...       en
# 490  Flinders University has made the devastating d...       fr
#
# [420 rows x 8 columns]

# %%
# Comprobación solidez de datos y consistencia
# Extraer solo el país de la columna 'creator_location'
df_filtered['creator_location'] = df_filtered['creator_location'].str.split(',').str[-1].str.strip()
df_filtered['creator_location'].value_counts()
df_filtered
# Out:
# C:\Users\fundacion\AppData\Local\Temp\ipykernel_4968\1994244992.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['creator_location'] = df_filtered['creator_location'].str.split(',').str[-1].str.strip()
#      test_idx                                              title  \
# 0           0                      Get my case heard for neglect
# 1           1  JUSTICE POUR JOE ET DAX: pour une peine exempl...
# 2           2   Mandatory Course in Mental Health for Highschool
# 3           3  Stop coronavirus - call for permanent ban on c...
# 4           4  Chiedere alle Nazioni Unite che il 2018 sia l'...
# ..        ...                                                ...
# 484       484  Support the Northwest's Clean & Equitable Ener...
# 486       486  Call for Emergency Medical Care for Children S...
# 488       488  Petition the International Maritime Organizati...
# 489       489                       Keep the Arts in Our Schools
# 490       490  Save Adelaide's arts community! Save Flinders ...
#
#                                            description  \
# 0    son in another empty labor and delivery room l...
# 1    Le 13 Février 2018, 3 chiens étaient déposés c...
# 2    In any given year, 1 in 5 people in Canada wil...
# 3    Français\nрусский \nPlease take action to supp...
# 4    population?- induced as they are by violence, ...
# ..                                                 ...
# 484  heal our oceans.\nIf we genuinely want our cle...
# 486  relief to places devastated by natural disaste...
# 488  public support in advance of this meeting will...
# 489  Talbot County Public Schools have decided to c...
# 490  Creative Arts (Drama) aka The Drama Centre. Fo...
#
#                                                 target creator_location  \
# 0    ['Virginia Governor', 'St francis hospital', '...    United States
# 1    ['Pétition adressée à Nicole Belloubet', 'Cyri...           France
# 2    ['The Minister Of Education', 'Halton Catholic...           Canada
# 3    ["National People's Congress (NPC)", 'WHO', 'O...   United Kingdom
# 4    ['Petizione diretta a Assemblea Generale Nazio...           Italia
# ..                                                 ...              ...
# 484  ['Senator Maria Cantwell', 'Senator Patty Murr...    United States
# 486  ['Secretary Alex Azar', 'Secretary Kevin McAle...    United States
# 488      ['International Maritime Organization (IMO)']   United Kingdom
# 489                   ['Talbot County Public Schools']    United States
# 490                                        ['artists']        Australia
#
#      supporters                                       full_content language
# 0        149447  On 3/12/17 I was at home talking to my sister ...       en
# 1         53919  Le 13 Février 2018, 3 chiens étaient déposés c...       fr
# 2         30635  In any given year, 1 in 5 people in Canada wil...       en
# 3         48004  Français\n\nрусский\n\nPlease take action to s...       en
# 4           436  [ITA] Se osservate la lista delle annate inter...       it
# ..          ...                                                ...      ...
# 484        3233  PLEASE SHARE WITH YOUR FRIENDS!\n\nIf we truly...       en
# 486      159178  Dear Secretary Azar, Acting Secretary McAleena...       en
# 488       89876  In May 2021, the MV X-Press Pearl spilt 1,680 ...       en
# 489        4565  Talbot County Public Schools have decided to c...       en
# 490        8616  Flinders University has made the devastating d...       fr
#
# [420 rows x 8 columns]

# %%
df_filtered.dtypes
# Out:
# test_idx             int64
# title               object
# description         object
# target              object
# creator_location    object
# supporters           int64
# full_content        object
# language            object
# dtype: object

# %% [markdown]
# ## TRADUCIR AL INGLÉS LAS PETICIONES

# %%
# %pip install googletrans==3.1.0a0
# Out:
# Requirement already satisfied: googletrans==3.1.0a0 in c:\users\fundacion\anaconda3\lib\site-packages (3.1.0a0)
# Requirement already satisfied: httpx==0.13.3 in c:\users\fundacion\anaconda3\lib\site-packages (from googletrans==3.1.0a0) (0.13.3)
# Requirement already satisfied: sniffio in c:\users\fundacion\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans==3.1.0a0) (1.2.0)
# Requirement already satisfied: hstspreload in c:\users\fundacion\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2023.1.1)
# Requirement already satisfied: httpcore==0.9.* in c:\users\fundacion\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans==3.1.0a0) (0.9.1)
# Requirement already satisfied: certifi in c:\users\fundacion\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2023.5.7)
# Requirement already satisfied: chardet==3.* in c:\users\fundacion\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans==3.1.0a0) (3.0.4)
# Requirement already satisfied: rfc3986<2,>=1.3 in c:\users\fundacion\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans==3.1.0a0) (1.5.0)
# Requirement already satisfied: idna==2.* in c:\users\fundacion\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2.10)
# Requirement already satisfied: h2==3.* in c:\users\fundacion\anaconda3\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (3.2.0)
# Requirement already satisfied: h11<0.10,>=0.8 in c:\users\fundacion\anaconda3\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (0.9.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in c:\users\fundacion\anaconda3\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in c:\users\fundacion\anaconda3\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (3.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from googletrans import Translator
translator = Translator(service_urls=['translate.googleapis.com'])

# Definir una función para traducir una columna
def translate_column(column):
    translated_column = []
    for text in column:
        translation = translator.translate(text,dest='en').text
        translated_column.append(translation)
    return translated_column

# Traducir la columna 'title' y almacenar los resultados en una nueva columna
df_filtered["title_translated"] = translate_column(df_filtered["title"])

# Traducir la columna 'description' y almacenar los resultados en una nueva columna
df_filtered["description_translated"] = translate_column(df_filtered["description"])

# Traducir la columna 'full_content' y almacenar los resultados en una nueva columna
df_filtered["full_content_translated"] = translate_column(df_filtered["full_content"])

# Mostrar el dataframe resultante
df_filtered
# Out:
# C:\Users\fundacion\AppData\Local\Temp\ipykernel_4968\3020695107.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered["title_translated"] = translate_column(df_filtered["title"])
# C:\Users\fundacion\AppData\Local\Temp\ipykernel_4968\3020695107.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered["description_translated"] = translate_column(df_filtered["description"])
# C:\Users\fundacion\AppData\Local\Temp\ipykernel_4968\3020695107.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered["full_content_translated"] = translate_column(df_filtered["full_content"])
#      test_idx                                              title  \
# 0           0                      Get my case heard for neglect
# 1           1  JUSTICE POUR JOE ET DAX: pour une peine exempl...
# 2           2   Mandatory Course in Mental Health for Highschool
# 3           3  Stop coronavirus - call for permanent ban on c...
# 4           4  Chiedere alle Nazioni Unite che il 2018 sia l'...
# ..        ...                                                ...
# 484       484  Support the Northwest's Clean & Equitable Ener...
# 486       486  Call for Emergency Medical Care for Children S...
# 488       488  Petition the International Maritime Organizati...
# 489       489                       Keep the Arts in Our Schools
# 490       490  Save Adelaide's arts community! Save Flinders ...
#
#                                            description  \
# 0    son in another empty labor and delivery room l...
# 1    Le 13 Février 2018, 3 chiens étaient déposés c...
# 2    In any given year, 1 in 5 people in Canada wil...
# 3    Français\nрусский \nPlease take action to supp...
# 4    population?- induced as they are by violence, ...
# ..                                                 ...
# 484  heal our oceans.\nIf we genuinely want our cle...
# 486  relief to places devastated by natural disaste...
# 488  public support in advance of this meeting will...
# 489  Talbot County Public Schools have decided to c...
# 490  Creative Arts (Drama) aka The Drama Centre. Fo...
#
#                                                 target creator_location  \
# 0    ['Virginia Governor', 'St francis hospital', '...    United States
# 1    ['Pétition adressée à Nicole Belloubet', 'Cyri...           France
# 2    ['The Minister Of Education', 'Halton Catholic...           Canada
# 3    ["National People's Congress (NPC)", 'WHO', 'O...   United Kingdom
# 4    ['Petizione diretta a Assemblea Generale Nazio...           Italia
# ..                                                 ...              ...
# 484  ['Senator Maria Cantwell', 'Senator Patty Murr...    United States
# 486  ['Secretary Alex Azar', 'Secretary Kevin McAle...    United States
# 488      ['International Maritime Organization (IMO)']   United Kingdom
# 489                   ['Talbot County Public Schools']    United States
# 490                                        ['artists']        Australia
#
#      supporters                                       full_content language  \
# 0        149447  On 3/12/17 I was at home talking to my sister ...       en
# 1         53919  Le 13 Février 2018, 3 chiens étaient déposés c...       fr
# 2         30635  In any given year, 1 in 5 people in Canada wil...       en
# 3         48004  Français\n\nрусский\n\nPlease take action to s...       en
# 4           436  [ITA] Se osservate la lista delle annate inter...       it
# ..          ...                                                ...      ...
# 484        3233  PLEASE SHARE WITH YOUR FRIENDS!\n\nIf we truly...       en
# 486      159178  Dear Secretary Azar, Acting Secretary McAleena...       en
# 488       89876  In May 2021, the MV X-Press Pearl spilt 1,680 ...       en
# 489        4565  Talbot County Public Schools have decided to c...       en
# 490        8616  Flinders University has made the devastating d...       fr
#
#                                       title_translated  \
# 0                        Get my case heard for neglect
# 1    JUSTICE FOR JOE AND DAX: for an exemplary sent...
# 2    Mandatory Course in Mental Health for High School
# 3    Stop coronavirus - call for permanent ban on c...
# 4    Call on the United Nations to make 2018 the IN...
# ..                                                 ...
# 484  Support the Northwest's Clean & Equitable Ener...
# 486  Call for Emergency Medical Care for Children S...
# 488  Petition the International Maritime Organizati...
# 489                       Keep the Arts in Our Schools
# 490  Save Adelaide's arts community! Save Flinders ...
#
#                                 description_translated  \
# 0    son in another empty labor and delivery room l...
# 1    On February 13, 2018, 3 dogs were dropped off ...
# 2    In any given year, 1 in 5 people in Canada wil...
# 3    Français\nрусский \nPlease take action to supp...
# 4    population?- induced as they are by violence, ...
# ..                                                 ...
# 484  heal our oceans.\nIf we genuinely want our cle...
# 486  relief to places devastated by natural disaste...
# 488  public support in advance of this meeting will...
# 489  Talbot County Public Schools have decided to c...
# 490  Creative Arts (Drama) aka The Drama Centre. Fo...
#
#                                full_content_translated
# 0    On 3/12/17 I was at home talking to my sister ...
# 1    On February 13, 2018, 3 dogs were dropped off ...
# 2    In any given year, 1 in 5 people in Canada wil...
# 3    Français\n\nрусский\n\nPlease take action to s...
# 4    [ENG] If you look at the list of international...
# ..                                                 ...
# 484  PLEASE SHARE WITH YOUR FRIENDS!\n\nIf we truly...
# 486  Dear Secretary Azar, Acting Secretary McAleena...
# 488  In May 2021, the MV X-Press Pearl spilt 1,680 ...
# 489  Talbot County Public Schools have decided to c...
# 490  Flinders University has made the devastating d...
#
# [420 rows x 11 columns]

# %% [markdown]
# ### ELIMINAR PALABRAS IRRELEVANTES (STOPWORDS)

# %%
# Obtener los stopwords en el idioma deseado (en este caso, inglés)
stop_words = set(stopwords.words('english'))

# Definir una función para eliminar las palabras irrelevantes de un texto
def remove_stopwords(text):
    tokens = word_tokenize(text.upper())
    filtered_tokens = [word for word in tokens if word.lower() not in stop_words]
    filtered_text = ' '.join(filtered_tokens)
    return filtered_text

# Aplicar la función remove_stopwords a la columna 'title_translated' del dataframe df_filtered
df_filtered['title_cleaned_nostopwords'] = df_filtered['title_translated'].apply(remove_stopwords)
df_filtered['description_nostopwords'] = df_filtered['description_translated'].apply(remove_stopwords)
df_filtered['full_content_nostopwords'] = df_filtered['full_content_translated'].apply(remove_stopwords)

# Mostrar el dataframe resultante
df_filtered
# Out:
# C:\Users\fundacion\AppData\Local\Temp\ipykernel_4968\3378628664.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['title_cleaned_nostopwords'] = df_filtered['title_translated'].apply(remove_stopwords)
# C:\Users\fundacion\AppData\Local\Temp\ipykernel_4968\3378628664.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['description_nostopwords'] = df_filtered['description_translated'].apply(remove_stopwords)
# C:\Users\fundacion\AppData\Local\Temp\ipykernel_4968\3378628664.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['full_content_nostopwords'] = df_filtered['full_content_translated'].apply(remove_stopwords)
#      test_idx                                              title  \
# 0           0                      Get my case heard for neglect
# 1           1  JUSTICE POUR JOE ET DAX: pour une peine exempl...
# 2           2   Mandatory Course in Mental Health for Highschool
# 3           3  Stop coronavirus - call for permanent ban on c...
# 4           4  Chiedere alle Nazioni Unite che il 2018 sia l'...
# ..        ...                                                ...
# 484       484  Support the Northwest's Clean & Equitable Ener...
# 486       486  Call for Emergency Medical Care for Children S...
# 488       488  Petition the International Maritime Organizati...
# 489       489                       Keep the Arts in Our Schools
# 490       490  Save Adelaide's arts community! Save Flinders ...
#
#                                            description  \
# 0    son in another empty labor and delivery room l...
# 1    Le 13 Février 2018, 3 chiens étaient déposés c...
# 2    In any given year, 1 in 5 people in Canada wil...
# 3    Français\nрусский \nPlease take action to supp...
# 4    population?- induced as they are by violence, ...
# ..                                                 ...
# 484  heal our oceans.\nIf we genuinely want our cle...
# 486  relief to places devastated by natural disaste...
# 488  public support in advance of this meeting will...
# 489  Talbot County Public Schools have decided to c...
# 490  Creative Arts (Drama) aka The Drama Centre. Fo...
#
#                                                 target creator_location  \
# 0    ['Virginia Governor', 'St francis hospital', '...    United States
# 1    ['Pétition adressée à Nicole Belloubet', 'Cyri...           France
# 2    ['The Minister Of Education', 'Halton Catholic...           Canada
# 3    ["National People's Congress (NPC)", 'WHO', 'O...   United Kingdom
# 4    ['Petizione diretta a Assemblea Generale Nazio...           Italia
# ..                                                 ...              ...
# 484  ['Senator Maria Cantwell', 'Senator Patty Murr...    United States
# 486  ['Secretary Alex Azar', 'Secretary Kevin McAle...    United States
# 488      ['International Maritime Organization (IMO)']   United Kingdom
# 489                   ['Talbot County Public Schools']    United States
# 490                                        ['artists']        Australia
#
#      supporters                                       full_content language  \
# 0        149447  On 3/12/17 I was at home talking to my sister ...       en
# 1         53919  Le 13 Février 2018, 3 chiens étaient déposés c...       fr
# 2         30635  In any given year, 1 in 5 people in Canada wil...       en
# 3         48004  Français\n\nрусский\n\nPlease take action to s...       en
# 4           436  [ITA] Se osservate la lista delle annate inter...       it
# ..          ...                                                ...      ...
# 484        3233  PLEASE SHARE WITH YOUR FRIENDS!\n\nIf we truly...       en
# 486      159178  Dear Secretary Azar, Acting Secretary McAleena...       en
# 488       89876  In May 2021, the MV X-Press Pearl spilt 1,680 ...       en
# 489        4565  Talbot County Public Schools have decided to c...       en
# 490        8616  Flinders University has made the devastating d...       fr
#
#                                       title_translated  \
# 0                        Get my case heard for neglect
# 1    JUSTICE FOR JOE AND DAX: for an exemplary sent...
# 2    Mandatory Course in Mental Health for High School
# 3    Stop coronavirus - call for permanent ban on c...
# 4    Call on the United Nations to make 2018 the IN...
# ..                                                 ...
# 484  Support the Northwest's Clean & Equitable Ener...
# 486  Call for Emergency Medical Care for Children S...
# 488  Petition the International Maritime Organizati...
# 489                       Keep the Arts in Our Schools
# 490  Save Adelaide's arts community! Save Flinders ...
#
#                                 description_translated  \
# 0    son in another empty labor and delivery room l...
# 1    On February 13, 2018, 3 dogs were dropped off ...
# 2    In any given year, 1 in 5 people in Canada wil...
# 3    Français\nрусский \nPlease take action to supp...
# 4    population?- induced as they are by violence, ...
# ..                                                 ...
# 484  heal our oceans.\nIf we genuinely want our cle...
# 486  relief to places devastated by natural disaste...
# 488  public support in advance of this meeting will...
# 489  Talbot County Public Schools have decided to c...
# 490  Creative Arts (Drama) aka The Drama Centre. Fo...
#
#                                full_content_translated  \
# 0    On 3/12/17 I was at home talking to my sister ...
# 1    On February 13, 2018, 3 dogs were dropped off ...
# 2    In any given year, 1 in 5 people in Canada wil...
# 3    Français\n\nрусский\n\nPlease take action to s...
# 4    [ENG] If you look at the list of international...
# ..                                                 ...
# 484  PLEASE SHARE WITH YOUR FRIENDS!\n\nIf we truly...
# 486  Dear Secretary Azar, Acting Secretary McAleena...
# 488  In May 2021, the MV X-Press Pearl spilt 1,680 ...
# 489  Talbot County Public Schools have decided to c...
# 490  Flinders University has made the devastating d...
#
#                              title_cleaned_nostopwords  \
# 0                               GET CASE HEARD NEGLECT
# 1               JUSTICE JOE DAX : EXEMPLARY SENTENCE !
# 2           MANDATORY COURSE MENTAL HEALTH HIGH SCHOOL
# 3    STOP CORONAVIRUS - CALL PERMANENT BAN COMMERCI...
# 4    CALL UNITED NATIONS MAKE 2018 INTERNATIONAL YE...
# ..                                                 ...
# 484  SUPPORT NORTHWEST 'S CLEAN & EQUITABLE ENERGY ...
# 486  CALL EMERGENCY MEDICAL CARE CHILDREN SEEKING A...
# 488  PETITION INTERNATIONAL MARITIME ORGANIZATION S...
# 489                                  KEEP ARTS SCHOOLS
# 490  SAVE ADELAIDE 'S ARTS COMMUNITY ! SAVE FLINDER...
#
#                                description_nostopwords  \
# 0    SON ANOTHER EMPTY LABOR DELIVERY ROOM LET ANYO...
# 1    FEBRUARY 13 , 2018 , 3 DOGS DROPPED BULKY VULG...
# 2    GIVEN YEAR , 1 5 PEOPLE CANADA PERSONALLY EXPE...
# 3    FRANÇAIS РУССКИЙ PLEASE TAKE ACTION SUPPORT CO...
# 4    POPULATION ? - INDUCED VIOLENCE , LAND/WATER G...
# ..                                                 ...
# 484  HEAL OCEANS . GENUINELY WANT CLEAN ENERGY FUTU...
# 486  RELIEF PLACES DEVASTATED NATURAL DISASTERS FAM...
# 488  PUBLIC SUPPORT ADVANCE MEETING ENORMOUSLY HELP...
# 489  TALBOT COUNTY PUBLIC SCHOOLS DECIDED CUT FUNDS...
# 490  CREATIVE ARTS ( DRAMA ) AKA DRAMA CENTRE . 50 ...
#
#                               full_content_nostopwords
# 0    3/12/17 HOME TALKING SISTER PHONE WATER BROKE ...
# 1    FEBRUARY 13 , 2018 , 3 DOGS DROPPED BULKY VULG...
# 2    GIVEN YEAR , 1 5 PEOPLE CANADA PERSONALLY EXPE...
# 3    FRANÇAIS РУССКИЙ PLEASE TAKE ACTION SUPPORT CO...
# 4    [ ENG ] LOOK LIST INTERNATIONAL VINTAGES PROMO...
# ..                                                 ...
# 484  PLEASE SHARE FRIENDS ! TRULY WANT SAVE SALMON ...
# 486  DEAR SECRETARY AZAR , ACTING SECRETARY MCALEEN...
# 488  MAY 2021 , MV X-PRESS PEARL SPILT 1,680 TONNES...
# 489  TALBOT COUNTY PUBLIC SCHOOLS DECIDED CUT FUNDS...
# 490  FLINDERS UNIVERSITY MADE DEVASTATING DECISION ...
#
# [420 rows x 14 columns]

# %% [markdown]
# ### CONTAR LAS PALABRAS MÁS REPETIDAS

# %% [markdown]
# #### CON LEMATIZACION

# %%
from collections import Counter

# Inicializar el lematizador
lemmatizer = WordNetLemmatizer()

# Función para lematizar una lista de palabras
def lemmatize_words(words):
    return [lemmatizer.lemmatize(word) for word in words]

# Obtener las palabras de la columna 'title_cleaned_nostopwords'
all_words = ' '.join(df_filtered['title_cleaned_nostopwords']).split()

# Lematizar las palabras
lemmatized_words = lemmatize_words(df_filtered['title_cleaned_nostopwords'])

# Contar la frecuencia de cada palabra lematizada
word_counts = Counter(lemmatized_words)

# Obtener las palabras más repetidas y mostrarlas en orden descendente
most_common_words = word_counts.most_common(20)

# Mostrar las palabras más repetidas
print('Palabras más repetidas (con lematización):')
for word, count in most_common_words:
    print(f'{word}: {count}')
# Out:
# Palabras más repetidas (con lematización):
# NEED UK-WIDE CLIMATE EMERGENCY ACTION PLAN !: 3
# SET CONSISTENT PUNISHMENT GUIDELINES NFL PLAYERS COMMIT VIOLENCE WOMEN: 2
# CORRUPTION: 2
# PREVENT PASSING EDUCATION LEGISLATION AMENDMENT BILL NSW .: 2
# SAFEGUARD DISABILITY RIGHTS - SIGN UN PROTOCOL: 2
# GET CASE HEARD NEGLECT: 1
# JUSTICE JOE DAX : EXEMPLARY SENTENCE !: 1
# MANDATORY COURSE MENTAL HEALTH HIGH SCHOOL: 1
# STOP CORONAVIRUS - CALL PERMANENT BAN COMMERCIAL WILDLIFE BREEDING , MARKETS & TRADE: 1
# CALL UNITED NATIONS MAKE 2018 INTERNATIONAL YEAR MIGRATION: 1
# SAVE PATIENTS ’ RIGHTS: 1
# STOP WRECKING CLIMATE - DITCH PLANS BUILD UK ’ BIGGEST GAS PLANT: 1
# STOP SEXUAL VIOLENCE WOMEN CHILE: 1
# INEQUALITY SCHOOLS: 1
# CP , LEARN FRENCH !: 1
# BRING BACK TRANS RIGHTS HEALTHCARE: 1
# REMOVE POLICE NINE PUBLIC HOUSING BUILDINGS: 1
# CHANGE NEW ZEALAND 'S IMMIGRATION LAW RECOGNISE OVERSEAS HOSPITALITY STAFFS CONTRIBUTION: 1
# LET 'S SAVE TIRE SCHOOL PALESTINE ! # THETYRESCHOOL: 1
# STOP ANIMAL CRUELTY: 1

# %% [markdown]
# #### SOLO PALABRAS MÁS UTILIZADAS

# %%
import re


# Unir todas las palabras en una lista y eliminar los signos de puntuación
all_words = ' '.join(df_filtered['title_cleaned_nostopwords'])
all_words += ' '.join(df_filtered['description_nostopwords'])
all_words += ' '.join(df_filtered['full_content_nostopwords'])
all_words = re.findall(r'\b\w{2,}\b', all_words)

# Contar la frecuencia de cada palabra
word_counts = Counter(all_words)

# Obtener las palabras más repetidas y mostrarlas en orden descendente
most_common_words = word_counts.most_common(20)

# Mostrar las palabras más repetidas
print('Palabras más repetidas:')
for word, count in most_common_words:
    print(f'{word}: {count}')
# Out:
# Palabras más repetidas:
# DI: 755
# DE: 622
# PEOPLE: 601
# LA: 468
# US: 430
# HEALTH: 390
# RIGHTS: 379
# PETITION: 372
# GOVERNMENT: 366
# NEED: 349
# ONE: 342
# ALSO: 326
# WOULD: 326
# SUPPORT: 325
# EDUCATION: 321
# UN: 317
# WOMEN: 313
# HELP: 309
# FOOD: 305
# PER: 305

# %% [markdown]
# # EXPORTAR BBDD CLEANED

# %%
df_filtered
# Out:
#      test_idx                                              title  \
# 0           0                      Get my case heard for neglect
# 1           1  JUSTICE POUR JOE ET DAX: pour une peine exempl...
# 2           2   Mandatory Course in Mental Health for Highschool
# 3           3  Stop coronavirus - call for permanent ban on c...
# 4           4  Chiedere alle Nazioni Unite che il 2018 sia l'...
# ..        ...                                                ...
# 484       484  Support the Northwest's Clean & Equitable Ener...
# 486       486  Call for Emergency Medical Care for Children S...
# 488       488  Petition the International Maritime Organizati...
# 489       489                       Keep the Arts in Our Schools
# 490       490  Save Adelaide's arts community! Save Flinders ...
#
#                                            description  \
# 0    son in another empty labor and delivery room l...
# 1    Le 13 Février 2018, 3 chiens étaient déposés c...
# 2    In any given year, 1 in 5 people in Canada wil...
# 3    Français\nрусский \nPlease take action to supp...
# 4    population?- induced as they are by violence, ...
# ..                                                 ...
# 484  heal our oceans.\nIf we genuinely want our cle...
# 486  relief to places devastated by natural disaste...
# 488  public support in advance of this meeting will...
# 489  Talbot County Public Schools have decided to c...
# 490  Creative Arts (Drama) aka The Drama Centre. Fo...
#
#                                                 target creator_location  \
# 0    ['Virginia Governor', 'St francis hospital', '...    United States
# 1    ['Pétition adressée à Nicole Belloubet', 'Cyri...           France
# 2    ['The Minister Of Education', 'Halton Catholic...           Canada
# 3    ["National People's Congress (NPC)", 'WHO', 'O...   United Kingdom
# 4    ['Petizione diretta a Assemblea Generale Nazio...           Italia
# ..                                                 ...              ...
# 484  ['Senator Maria Cantwell', 'Senator Patty Murr...    United States
# 486  ['Secretary Alex Azar', 'Secretary Kevin McAle...    United States
# 488      ['International Maritime Organization (IMO)']   United Kingdom
# 489                   ['Talbot County Public Schools']    United States
# 490                                        ['artists']        Australia
#
#      supporters                                       full_content language  \
# 0        149447  On 3/12/17 I was at home talking to my sister ...       en
# 1         53919  Le 13 Février 2018, 3 chiens étaient déposés c...       fr
# 2         30635  In any given year, 1 in 5 people in Canada wil...       en
# 3         48004  Français\n\nрусский\n\nPlease take action to s...       en
# 4           436  [ITA] Se osservate la lista delle annate inter...       it
# ..          ...                                                ...      ...
# 484        3233  PLEASE SHARE WITH YOUR FRIENDS!\n\nIf we truly...       en
# 486      159178  Dear Secretary Azar, Acting Secretary McAleena...       en
# 488       89876  In May 2021, the MV X-Press Pearl spilt 1,680 ...       en
# 489        4565  Talbot County Public Schools have decided to c...       en
# 490        8616  Flinders University has made the devastating d...       fr
#
#                                       title_translated  \
# 0                        Get my case heard for neglect
# 1    JUSTICE FOR JOE AND DAX: for an exemplary sent...
# 2    Mandatory Course in Mental Health for High School
# 3    Stop coronavirus - call for permanent ban on c...
# 4    Call on the United Nations to make 2018 the IN...
# ..                                                 ...
# 484  Support the Northwest's Clean & Equitable Ener...
# 486  Call for Emergency Medical Care for Children S...
# 488  Petition the International Maritime Organizati...
# 489                       Keep the Arts in Our Schools
# 490  Save Adelaide's arts community! Save Flinders ...
#
#                                 description_translated  \
# 0    son in another empty labor and delivery room l...
# 1    On February 13, 2018, 3 dogs were dropped off ...
# 2    In any given year, 1 in 5 people in Canada wil...
# 3    Français\nрусский \nPlease take action to supp...
# 4    population?- induced as they are by violence, ...
# ..                                                 ...
# 484  heal our oceans.\nIf we genuinely want our cle...
# 486  relief to places devastated by natural disaste...
# 488  public support in advance of this meeting will...
# 489  Talbot County Public Schools have decided to c...
# 490  Creative Arts (Drama) aka The Drama Centre. Fo...
#
#                                full_content_translated  \
# 0    On 3/12/17 I was at home talking to my sister ...
# 1    On February 13, 2018, 3 dogs were dropped off ...
# 2    In any given year, 1 in 5 people in Canada wil...
# 3    Français\n\nрусский\n\nPlease take action to s...
# 4    [ENG] If you look at the list of international...
# ..                                                 ...
# 484  PLEASE SHARE WITH YOUR FRIENDS!\n\nIf we truly...
# 486  Dear Secretary Azar, Acting Secretary McAleena...
# 488  In May 2021, the MV X-Press Pearl spilt 1,680 ...
# 489  Talbot County Public Schools have decided to c...
# 490  Flinders University has made the devastating d...
#
#                              title_cleaned_nostopwords  \
# 0                               GET CASE HEARD NEGLECT
# 1               JUSTICE JOE DAX : EXEMPLARY SENTENCE !
# 2           MANDATORY COURSE MENTAL HEALTH HIGH SCHOOL
# 3    STOP CORONAVIRUS - CALL PERMANENT BAN COMMERCI...
# 4    CALL UNITED NATIONS MAKE 2018 INTERNATIONAL YE...
# ..                                                 ...
# 484  SUPPORT NORTHWEST 'S CLEAN & EQUITABLE ENERGY ...
# 486  CALL EMERGENCY MEDICAL CARE CHILDREN SEEKING A...
# 488  PETITION INTERNATIONAL MARITIME ORGANIZATION S...
# 489                                  KEEP ARTS SCHOOLS
# 490  SAVE ADELAIDE 'S ARTS COMMUNITY ! SAVE FLINDER...
#
#                                description_nostopwords  \
# 0    SON ANOTHER EMPTY LABOR DELIVERY ROOM LET ANYO...
# 1    FEBRUARY 13 , 2018 , 3 DOGS DROPPED BULKY VULG...
# 2    GIVEN YEAR , 1 5 PEOPLE CANADA PERSONALLY EXPE...
# 3    FRANÇAIS РУССКИЙ PLEASE TAKE ACTION SUPPORT CO...
# 4    POPULATION ? - INDUCED VIOLENCE , LAND/WATER G...
# ..                                                 ...
# 484  HEAL OCEANS . GENUINELY WANT CLEAN ENERGY FUTU...
# 486  RELIEF PLACES DEVASTATED NATURAL DISASTERS FAM...
# 488  PUBLIC SUPPORT ADVANCE MEETING ENORMOUSLY HELP...
# 489  TALBOT COUNTY PUBLIC SCHOOLS DECIDED CUT FUNDS...
# 490  CREATIVE ARTS ( DRAMA ) AKA DRAMA CENTRE . 50 ...
#
#                               full_content_nostopwords
# 0    3/12/17 HOME TALKING SISTER PHONE WATER BROKE ...
# 1    FEBRUARY 13 , 2018 , 3 DOGS DROPPED BULKY VULG...
# 2    GIVEN YEAR , 1 5 PEOPLE CANADA PERSONALLY EXPE...
# 3    FRANÇAIS РУССКИЙ PLEASE TAKE ACTION SUPPORT CO...
# 4    [ ENG ] LOOK LIST INTERNATIONAL VINTAGES PROMO...
# ..                                                 ...
# 484  PLEASE SHARE FRIENDS ! TRULY WANT SAVE SALMON ...
# 486  DEAR SECRETARY AZAR , ACTING SECRETARY MCALEEN...
# 488  MAY 2021 , MV X-PRESS PEARL SPILT 1,680 TONNES...
# 489  TALBOT COUNTY PUBLIC SCHOOLS DECIDED CUT FUNDS...
# 490  FLINDERS UNIVERSITY MADE DEVASTATING DECISION ...
#
# [420 rows x 14 columns]

# %%
# Crear una nueva DataFrame con las columnas específicas
df_clean_test = df_filtered[['test_idx','title_cleaned_nostopwords', 'description_nostopwords', 'full_content_nostopwords', 'supporters']].copy()
df_clean_test.to_csv('dataframe_test.csv', index=False)
df_clean_test
# Out:
#      test_idx                          title_cleaned_nostopwords  \
# 0           0                             GET CASE HEARD NEGLECT
# 1           1             JUSTICE JOE DAX : EXEMPLARY SENTENCE !
# 2           2         MANDATORY COURSE MENTAL HEALTH HIGH SCHOOL
# 3           3  STOP CORONAVIRUS - CALL PERMANENT BAN COMMERCI...
# 4           4  CALL UNITED NATIONS MAKE 2018 INTERNATIONAL YE...
# ..        ...                                                ...
# 484       484  SUPPORT NORTHWEST 'S CLEAN & EQUITABLE ENERGY ...
# 486       486  CALL EMERGENCY MEDICAL CARE CHILDREN SEEKING A...
# 488       488  PETITION INTERNATIONAL MARITIME ORGANIZATION S...
# 489       489                                  KEEP ARTS SCHOOLS
# 490       490  SAVE ADELAIDE 'S ARTS COMMUNITY ! SAVE FLINDER...
#
#                                description_nostopwords  \
# 0    SON ANOTHER EMPTY LABOR DELIVERY ROOM LET ANYO...
# 1    FEBRUARY 13 , 2018 , 3 DOGS DROPPED BULKY VULG...
# 2    GIVEN YEAR , 1 5 PEOPLE CANADA PERSONALLY EXPE...
# 3    FRANÇAIS РУССКИЙ PLEASE TAKE ACTION SUPPORT CO...
# 4    POPULATION ? - INDUCED VIOLENCE , LAND/WATER G...
# ..                                                 ...
# 484  HEAL OCEANS . GENUINELY WANT CLEAN ENERGY FUTU...
# 486  RELIEF PLACES DEVASTATED NATURAL DISASTERS FAM...
# 488  PUBLIC SUPPORT ADVANCE MEETING ENORMOUSLY HELP...
# 489  TALBOT COUNTY PUBLIC SCHOOLS DECIDED CUT FUNDS...
# 490  CREATIVE ARTS ( DRAMA ) AKA DRAMA CENTRE . 50 ...
#
#                               full_content_nostopwords  supporters
# 0    3/12/17 HOME TALKING SISTER PHONE WATER BROKE ...      149447
# 1    FEBRUARY 13 , 2018 , 3 DOGS DROPPED BULKY VULG...       53919
# 2    GIVEN YEAR , 1 5 PEOPLE CANADA PERSONALLY EXPE...       30635
# 3    FRANÇAIS РУССКИЙ PLEASE TAKE ACTION SUPPORT CO...       48004
# 4    [ ENG ] LOOK LIST INTERNATIONAL VINTAGES PROMO...         436
# ..                                                 ...         ...
# 484  PLEASE SHARE FRIENDS ! TRULY WANT SAVE SALMON ...        3233
# 486  DEAR SECRETARY AZAR , ACTING SECRETARY MCALEEN...      159178
# 488  MAY 2021 , MV X-PRESS PEARL SPILT 1,680 TONNES...       89876
# 489  TALBOT COUNTY PUBLIC SCHOOLS DECIDED CUT FUNDS...        4565
# 490  FLINDERS UNIVERSITY MADE DEVASTATING DECISION ...        8616
#
# [420 rows x 5 columns]

# %% [markdown]
# #### PLOTEAR IMAGEN CON PALABRAS MAS REPETIDAS

# %%
# %pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\fundacion\anaconda3\lib\site-packages (1.9.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy>=1.6.1 in c:\users\fundacion\anaconda3\lib\site-packages (from wordcloud) (1.23.5)
# Requirement already satisfied: matplotlib in c:\users\fundacion\anaconda3\lib\site-packages (from wordcloud) (3.7.0)
# Requirement already satisfied: pillow in c:\users\fundacion\anaconda3\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\fundacion\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\fundacion\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\fundacion\anaconda3\lib\site-packages (from matplotlib->wordcloud) (22.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\fundacion\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\fundacion\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\fundacion\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\fundacion\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: six>=1.5 in c:\users\fundacion\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# Crear una wordcloud con las palabras más repetidas
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(dict(most_common_words))

# Mostrar la wordcloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
